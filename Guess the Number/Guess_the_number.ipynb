# %%
import random

lives = 10
#Function to generate a random number
def random_number_generator(start_num,end_num):
    guessing_number = random.randint(start_num,end_num)
    return guessing_number

play = True
while play:
    print('''
   _____                       _   _                                  _               
  / ____|                     | | | |                                | |              
 | |  __ _   _  ___  ___ ___  | |_| |__   ___   _ __  _   _ _ __ ___ | |__   ___ _ __ 
 | | |_ | | | |/ _ \/ __/ __||__| _ \ / _ \ | _ \| | | |   _ \| _ \ / _ \ __|
 | |__| | |_| |  __/\__\__ \ |  |_| | | |  __/ | | | | |_| | | | | | | |_) |  __/ |   
  \_____|\___|\___||___/___/  \__|_| |_|\___| |_| |_|\___|_| |_| |_|___/ \___|_|   
                                                                                      
                                                                                      
''')
    number_question = random_number_generator(1,100)
    difficulty = input("\nPlease choose the difficulty of the game. Easy or Hard ?")
    if difficulty =='Hard': 
        lives=5
        while lives>0 and number_question!=user_choice:
            user_choice = int(input(f"\nNow ! Guess the number. You have {lives} lives for Hard Mode"))
            if user_choice>number_question:
                print("\Your number is higher than actual number ")
            elif user_choice<number_question:
                print("\Your number is lower than actual number ")
            elif user_choice==number_question:
                print("\nYou have guessed the number ",number_question)
                lives=0
            lives-=1
            if lives==0:
                print("\nYou have lost all lives. The number was ",number_question)
    if difficulty =='Easy': 
        lives=10
        while lives>0 and number_question!=user_choice:
            user_choice = int(input(f"\nNow ! Guess the number. You have {lives} lives for Hard Mode"))
            if user_choice>number_question:
                print("\Your number is higher than actual number ")
            elif user_choice<number_question:
                print("\Your number is lower than actual number ")
            elif user_choice==number_question:
                print("\nYou have guessed the number ",number_question)
                lives=0
            lives-=1
            if lives==0:
                print("\nYou have lost all lives. The number was ",number_question)
    
    
    
    choice = input("\nDo you want to play again !? y or n ")
    if choice =='n':
        play = False
# Out:
#    _____                       _   _                                  _
#   / ____|                     | | | |                                | |
#  | |  __ _   _  ___  ___ ___  | |_| |__   ___   _ __  _   _ _ __ ___ | |__   ___ _ __
#  | | |_ | | | |/ _ \/ __/ __||__| _ \ / _ \ | _ \| | | |   _ \| _ \ / _ \ __|
#  | |__| | |_| |  __/\__\__ \ |  |_| | | |  __/ | | | | |_| | | | | | | |_) |  __/ |
#   \_____|\___|\___||___/___/  \__|_| |_|\___| |_| |_|\___|_| |_| |_|___/ \___|_|
#
#
#
#
# Please choose the difficulty of the game. Easy or Hard ?Easy
#
# Now ! Guess the number. You have 10 lives for Hard Mode50
# \Your number is lower than actual number
#
# Now ! Guess the number. You have 9 lives for Hard Mode65
# \Your number is lower than actual number
#
# Now ! Guess the number. You have 8 lives for Hard Mode75
#
# You have guessed the number  75
#
# Do you want to play again !? y or n n
